# %% [markdown]
# **Import Library**

# %%
import pandas as pd

# %%
set = pd.read_csv('../Data/top20_set_prices.csv')

# %% [markdown]
# **Data cleaning for SET and S&P500**

# %% [markdown]
# **SET**

# %%
set.shape
# Out:
# (2664, 145)

# %%
set
# Out:
#            Price           Adj Close         Adj Close.1         Adj Close.2  \
# 0         Ticker           ADVANC.BK              AOT.BK              BBL.BK
# 1           Date                 NaN                 NaN                 NaN
# 2     2014-01-02  115.70769500732422  13.004045486450195  112.16766357421875
# 3     2014-01-03  121.27652740478516   12.87090015411377  113.85691833496094
# 4     2014-01-06  124.37032318115234  12.648985862731934  117.23546600341797
# ...          ...                 ...                 ...                 ...
# 2659  2024-12-03               296.0  61.209999084472656               150.5
# 2660  2024-12-04               289.0                61.5               151.5
# 2661  2024-12-06               295.0                61.0               152.0
# 2662  2024-12-09               295.0                60.5               153.0
# 2663  2024-12-11               289.0                61.5               151.0
#
# ...

# %%
# drop all the columns except for Adj Close
set = set[[col for col in set.columns if col.startswith(('Price', 'Adj'))]]

# %%
set.columns
# Out:
# Index(['Price', 'Adj Close', 'Adj Close.1', 'Adj Close.2', 'Adj Close.3',
#        'Adj Close.4', 'Adj Close.5', 'Adj Close.6', 'Adj Close.7',
#        'Adj Close.8', 'Adj Close.9', 'Adj Close.10', 'Adj Close.11',
#        'Adj Close.12', 'Adj Close.13', 'Adj Close.14', 'Adj Close.15',
#        'Adj Close.16', 'Adj Close.17', 'Adj Close.18', 'Adj Close.19',
#        'Adj Close.20', 'Adj Close.21', 'Adj Close.22', 'Adj Close.23'],
#       dtype='object')

# %%
# Reset the index by the name of the stocks 
set.columns = set.iloc[0]
# Drop all the stocks name rows and NaN rows 
set = set[2:]

# %%
set.isnull().sum()[set.isnull().sum() != 0]
# Out:
# 0
# CRC.BK     1498
# GULF.BK     958
# OR.BK      1735
# SCB.BK     2023
# dtype: int64

# %%
# Seperate the (CRC, GULF, OR, and SCB) into different 
the_rest = set[['CRC.BK', 'GULF.BK', 'OR.BK','SCB.BK']]
the_rest
# Out:
# 0    CRC.BK GULF.BK               OR.BK SCB.BK
# 2       NaN     NaN                 NaN    NaN
# 3       NaN     NaN                 NaN    NaN
# 4       NaN     NaN                 NaN    NaN
# 5       NaN     NaN                 NaN    NaN
# 6       NaN     NaN                 NaN    NaN
# ...     ...     ...                 ...    ...
# 2659   34.5    65.5  14.300000190734863  116.0
# 2660  33.75   63.25  14.100000381469727  118.0
# 2661   34.0    65.0  14.100000381469727  118.0
# 2662   34.0   64.25  13.899999618530273  118.5
# 2663  34.25   63.25  14.100000381469727  118.0
#
# [2662 rows x 4 columns]

# %%
main = set.drop(columns = ['CRC.BK', 'GULF.BK', 'OR.BK','SCB.BK'])
main = main.rename(columns ={'Ticker':'Date'})

# %%
# set date to date 
main['Date'] = pd.to_datetime(main['Date'])

# set date into index 
main = main.set_index('Date')

# %%
# Converting all the obj into float
for col in main.columns[1:21] :
        main[col] = main[col].astype(float)

# %%
# Export the file 
main.to_csv("../Data/SET_main.csv")
the_rest.to_csv("../Data/SET_residual.csv")

# %%
main
# Out:
# 0                    ADVANC.BK     AOT.BK      BBL.BK    BDMS.BK       BH.BK  \
# Date
# 2014-01-02  115.70769500732422  13.004045  112.167664   8.865041   68.680244
# 2014-01-03  121.27652740478516  12.870900  113.856918   8.824374   69.914032
# 2014-01-06  124.37032318115234  12.648986  117.235466   9.678345   69.091530
# 2014-01-07   129.9391326904297  13.447869  120.276161   9.556350   68.474625
# 2014-01-08  127.46409606933594  12.870900  119.938301   9.312360   67.446480
# ...                        ...        ...         ...        ...         ...
# 2024-12-03               296.0  61.209999  150.500000  26.000000  212.000000
# 2024-12-04               289.0  61.500000  151.500000  25.750000  211.000000
# 2024-12-06               295.0  61.000000  152.000000  25.500000  210.000000
# 2024-12-09               295.0  60.500000  153.000000  25.250000  202.000000
# 2024-12-11               289.0  61.500000  151.000000  25.250000  199.500000
#
# ...

# %% [markdown]
# **S&P500**

# %%
sp500 = pd.read_csv('../Data/top20_sp500_prices.csv')

# %%
# Drop all the columns except for Adj Close
sp500 = sp500.iloc[:, :21]
sp500
# Out:
#            Price           Adj Close         Adj Close.1         Adj Close.2  \
# 0         Ticker                AAPL                AMZN                AVGO
# 1           Date                 NaN                 NaN                 NaN
# 2     2014-01-02  17.234296798706055  19.898500442504883  3.9612834453582764
# 3     2014-01-03  16.855730056762695   19.82200050354004  3.9763312339782715
# 4     2014-01-06   16.94764518737793  19.681499481201172  3.9492456912994385
# ...          ...                 ...                 ...                 ...
# 2752  2024-12-05   243.0399932861328   220.5500030517578  170.47000122070312
# 2753  2024-12-06  242.83999633789062  227.02999877929688  179.52999877929688
# 2754  2024-12-09              246.75  226.08999633789062  178.94000244140625
# 2755  2024-12-10  247.77000427246094   225.0399932861328  171.80999755859375
# 2756  2024-12-11  246.49000549316406  230.25999450683594   183.1999969482422
#
# ...

# %%
# Reset the index by the name of the stocks 
sp500.columns = sp500.iloc[0]
# Drop all the stocks name rows and NaN rows 
sp500 = sp500[2:]

sp500
# Out:
# 0         Ticker                AAPL                AMZN                AVGO  \
# 2     2014-01-02  17.234296798706055  19.898500442504883  3.9612834453582764
# 3     2014-01-03  16.855730056762695   19.82200050354004  3.9763312339782715
# 4     2014-01-06   16.94764518737793  19.681499481201172  3.9492456912994385
# 5     2014-01-07  16.826440811157227  19.901500701904297  3.9868650436401367
# 6     2014-01-08   16.93300437927246   20.09600067138672   4.046302795410156
# ...          ...                 ...                 ...                 ...
# 2752  2024-12-05   243.0399932861328   220.5500030517578  170.47000122070312
# 2753  2024-12-06  242.83999633789062  227.02999877929688  179.52999877929688
# 2754  2024-12-09              246.75  226.08999633789062  178.94000244140625
# 2755  2024-12-10  247.77000427246094   225.0399932861328  171.80999755859375
# 2756  2024-12-11  246.49000549316406  230.25999450683594   183.1999969482422
#
# ...

# %%
# change name from price to Date
sp500 = sp500.rename(columns ={'Ticker':'Date'})
# set date to date 
sp500['Date'] = pd.to_datetime(sp500['Date'])

# set date into index 
# sp500 = sp500.set_index('Date')

# %%
# Converting all the obj into float
for col in sp500.columns[1:21] :
        sp500[col] = sp500[col].astype(float)

# %%
# Export the file 
sp500.to_csv("../Data/sp500_main.csv", index=False)

# %%
# sp500 = pd.read_csv('../Data/sp500_main.csv')

# %%
sp500
# Out:
# 0          Date        AAPL        AMZN        AVGO        COST        GOOG  \
# 2    2014-01-02   17.234297   19.898500    3.961283   94.369179   27.624825
# 3    2014-01-03   16.855730   19.822001    3.976331   93.952660   27.423307
# 4    2014-01-06   16.947645   19.681499    3.949246   93.239731   27.729059
# 5    2014-01-07   16.826441   19.901501    3.986865   92.807159   28.263626
# 6    2014-01-08   16.933004   20.096001    4.046303   91.357330   28.322445
# ...         ...         ...         ...         ...         ...         ...
# 2752 2024-12-05  243.039993  220.550003  170.470001  982.260010  174.112473
# 2753 2024-12-06  242.839996  227.029999  179.529999  992.609985  176.290009
# 2754 2024-12-09  246.750000  226.089996  178.940002  987.859985  177.100006
# 2755 2024-12-10  247.770004  225.039993  171.809998  993.400024  186.529999
# 2756 2024-12-11  246.490005  230.259995  183.199997  994.690002  196.710007
#
# ...
